# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gzip
import json

import pandas as pd
from tqdm import tqdm

# %%
with gzip.open(
    "/Users/olgabot/botryllus-data/2024-04-16__uniprotkb_ZNF292_OR_RNMT_OR_BMP3_OR_CFA__botryllus_bhf_matches.json.gz"
) as f:
    uniprot_data = json.load(f)

# %%
entry = uniprot_data["results"][0]

# %%
entry.keys()
# Out:
# dict_keys(['entryType', 'primaryAccession', 'secondaryAccessions', 'uniProtkbId', 'entryAudit', 'annotationScore', 'organism', 'proteinExistence', 'proteinDescription', 'genes', 'comments', 'features', 'keywords', 'references', 'uniProtKBCrossReferences', 'sequence', 'extraAttributes'])

# %%
# def add_subsequence_to_feature(feature, full_sequence):
#     start = feature["location"]["start"]["value"] - 1
#     end = feature["location"]["end"]["value"]
#     feature_seq = full_sequence[start:end]
#     length = len(feature_seq)
#     feature["sequence"] = {"value": feature_seq, "length": length}
#     return feature


# def parse_features(entry):
#     full_sequence = entry["sequence"]["value"]

#     sequence_features = []

#     for feature in entry["features"]:
#         feature = add_subsequence_to_feature(feature, full_sequence)
#         sequence_features.append(feature)
#     return sequence_features


# parse_features(entry)

# %%
def get_uniprot_gene_names(entry):
    if "genes" in entry:
        genes = ";".join(x["geneName"]["value"] for x in entry["genes"])
    else:
        genes = ""
    return genes

# %% [markdown]
# ## Make Sourmash signatures

# %%
import csv
import os

import sig2kmer

import sourmash
from sourmash.logging import set_quiet

set_quiet(True)


def create_signature_from_sequence(
    sequence: str,
    protein_ksizes=[27],
    seed=sourmash.DEFAULT_SEED,
    protein=False,
    dayhoff=False,
    hp=True,
    dna=False,
    num_hashes=0,
    track_abundance=True,
    scaled=1,
):
    """
    protein_ksizes : list of ints
        This is the length of the k-mer in the amino acid sequence
    """

    # Multiply by three to get DNA-based ksizes
    # This is necessary because all the ksizes in sourmash are relative to DNA
    dna_ksizes = [k * 3 for k in protein_ksizes]

    params = sourmash.command_compute.ComputeParameters(
        ksizes=dna_ksizes,
        seed=seed,
        protein=protein,
        dayhoff=dayhoff,
        hp=hp,
        dna=dna,
        num_hashes=num_hashes,
        track_abundance=track_abundance,
        scaled=scaled,
    )

    sig = sourmash.signature.SourmashSignature.from_params(params)

    sig.add_protein(sequence)
    return sig


def write_hashval_kmers(
    sequence: str,
    sig: sourmash.SourmashSignature,
    ksize: int,
    moltype: str,
    filename: str,
    entry: dict,
):
    """
    entry : dict
        One result from the Uniprot REST API response
    """
    columns = [
        "hashval",
        "kmer_in_sequence",
        "kmer_in_alphabet",
        "start",
        "accession",
        "uniprotkb_id",
        "organism_scientific_name",
        "organism_common_name",
        "organism_taxonid",
        "gene_name",
    ]

    # response

    with gzip.open(filename, "wt") as f:
        writer = csv.writer(f)
        writer.writerow(columns)
        genes = get_uniprot_gene_names(entry)

        for kmer_in_seq, kmer_encoded, hashval, i in sig2kmer.get_kmers_for_hashvals(
            sequence, sig.minhash.hashes.keys(), ksize, moltype, input_is_protein=True
        ):
            writer.writerow(
                [
                    str(hashval),
                    kmer_in_seq,
                    kmer_encoded,
                    i,
                    entry["primaryAccession"],
                    entry["uniProtkbId"],
                    entry["organism"]["scientificName"],
                    entry["organism"]["commonName"],
                    entry["organism"]["taxonId"],
                    genes,
                ]
            )

# %% [markdown]
# ## Iterate over entries and create kmer signatures

# %%
outdir = "/Users/olgabot/protein-job-search/2024-04-16--botryllus-known-matches"
# !mkdir -p $outdir

ksize = 24
moltype = "hp"

for entry in uniprot_data["results"]:
    sequence = entry["sequence"]["value"]

    sig = create_signature_from_sequence(sequence, protein_ksizes=[ksize], scaled=1)
    accession = entry["primaryAccession"]
    uniprotkbid = entry["uniProtkbId"]
    prefix = f"{accession}__{uniprotkbid}"

    filename = os.path.join(outdir, f"{prefix}.csv.gz")
    write_hashval_kmers(
        sequence, sig, ksize=ksize, moltype=moltype, filename=filename, entry=entry
    )
    sourmash.command_compute.save_siglist(
        [sig], os.path.join(outdir, f"{prefix}.sig.gz")
    )

# %%
# ! wc -l $outdir/*.csv.gz

# %% [markdown]
# ## Import botryllus sequence

# %%
botryllus_dir = "/Users/olgabot/botryllus/data/botryllus-proteins/"

botryllus_sigfile = os.path.join(botryllus_dir, "Bs_proteins.fa.hp.k24.scale5.sig")

# %% [markdown]
# ### Read botryllus kmer hashes

# %%
def read_hash_csv(hash_csv):
    df = pd.read_csv(hash_csv)

    # Force hashval to be strings to avoid overflow/underflow errors
    df["hashval"] = df["hashval"].astype(str)
    # df = df.set_index(["hashval"])
    return df

# %%
hash_csv = os.path.join(
    botryllus_dir, "Bs_proteins.fa.hp.k24.scale5.aggregated.kmers.csv"
)
botryllus_kmer_hashes = read_hash_csv(hash_csv)
# botryllus_kmer_hashes.index = botryllus_kmer_hashes.index.astype(str)
botryllus_kmer_hashes
# Out:
#                 kmer_in_sequence          kmer_in_alphabet  \
# 0       VHDTEQLLAQGHHEEETECGKYGK  hppppphhhphpppppppphphhp
# 1       TEQLLAQGHHEEETECGKYGKLPE  ppphhhphpppppppphphhphhp
# 2       EQLLAQGHHEEETECGKYGKLPEK  pphhhphpppppppphphhphhpp
# 3       ETECGKYGKLPEKGSECKKHGIFC  pppphphhphhpphpppppphhhp
# 4       KYGKLPEKGSECKKHGIFCRILTA  phhphhpphpppppphhhpphhph
# ...                          ...                       ...
# 303186  LEREIEAQQLVMLEAEIDCLQRRF  hppphphpphhhhphphpphppph
# 303187  EREIEAQQLVMLEAEIDCLQRRFE  ppphphpphhhhphphpphppphp
# 303188  MLEAEIDCLQRRFEDMESTWISRI  hhphphpphppphpphppphhpph
# 303189  EIDCLQRRFEDMESTWISRIDGTS  phpphppphpphppphhpphphpp
# 303190  QRRFEDMESTWISRIDGTSENCVK  ppphpphppphhpphphppppphp
#
#                     hashval          read_name           filename
# 0       1036020595944595459                BHF  Bs_proteins.fa.gz
# 1       2993707203445337902                BHF  Bs_proteins.fa.gz
# 2        973051056292048589                BHF  Bs_proteins.fa.gz
# 3        385192726330471768                BHF  Bs_proteins.fa.gz
# 4       1194029314525711201                BHF  Bs_proteins.fa.gz
# ...                     ...                ...                ...
# 303186  1833930335722081195  g72096.t1 frame:1  Bs_proteins.fa.gz
# 303187   616964295969867237  g72096.t1 frame:1  Bs_proteins.fa.gz
# 303188  1869927996039995699  g72096.t1 frame:1  Bs_proteins.fa.gz
# 303189   995001100309400823  g72096.t1 frame:1  Bs_proteins.fa.gz
# 303190  3221805479420536835  g72096.t1 frame:1  Bs_proteins.fa.gz
#
# [303191 rows x 5 columns]

# %%
bhf_hashes = botryllus_kmer_hashes.query('read_name == "BHF"')
bhf_hashes.head()
# Out:
#            kmer_in_sequence          kmer_in_alphabet              hashval  \
# 0  VHDTEQLLAQGHHEEETECGKYGK  hppppphhhphpppppppphphhp  1036020595944595459
# 1  TEQLLAQGHHEEETECGKYGKLPE  ppphhhphpppppppphphhphhp  2993707203445337902
# 2  EQLLAQGHHEEETECGKYGKLPEK  pphhhphpppppppphphhphhpp   973051056292048589
# 3  ETECGKYGKLPEKGSECKKHGIFC  pppphphhphhpphpppppphhhp   385192726330471768
# 4  KYGKLPEKGSECKKHGIFCRILTA  phhphhpphpppppphhhpphhph  1194029314525711201
#
#   read_name           filename
# 0       BHF  Bs_proteins.fa.gz
# 1       BHF  Bs_proteins.fa.gz
# 2       BHF  Bs_proteins.fa.gz
# 3       BHF  Bs_proteins.fa.gz
# 4       BHF  Bs_proteins.fa.gz

# %%
entry_to_gene_name = pd.Series(
    {x["primaryAccession"]: get_uniprot_gene_names(x) for x in uniprot_data["results"]}
)
entry_to_gene_name
# Out:
# O00327      BMAL1
# O00422      SAP18
# O14745     NHERF1
# O15393    TMPRSS2
# O43148       RNMT
#            ...
# Q5TA04     CFAP43
# Q5TA05     CFAP43
# Q6P495     ZNF292
# X5D9G8    CACNA1G
# X5D9M1    CACNA1G
# Length: 191, dtype: object

# %%
znf292_entries = entry_to_gene_name[entry_to_gene_name == "ZNF292"]
znf292_entries
# Out:
# O60281        ZNF292
# J3KNV1        ZNF292
# A0A8V8TP18    ZNF292
# A0A8V8TPC9    ZNF292
# A0A8V8TPI9    ZNF292
# A0A8V8TQW3    ZNF292
# E5RJG2        ZNF292
# H0YAU0        ZNF292
# H0YB79        ZNF292
# Q6P495        ZNF292
# dtype: object

# %%
znf292_csv = "/Users/olgabot/protein-job-search/2024-04-16--botryllus-known-matches/O60281__ZN292_HUMAN.csv.gz"

# %%
znf292_hashes = read_hash_csv(znf292_csv)
znf292_hashes
# Out:
#                    hashval          kmer_in_sequence  \
# 0     13638207749623269045  hhppphpppphpphphhphhphpp
# 1      8404708278310155067  hppphpppphpphphhphhphpph
# 2      8048618853620713690  ppphpppphpphphhphhphpphh
# 3     17517879030661681686  pphpppphpphphhphhphpphhp
# 4     17298076713827473283  phpppphpphphhphhphpphhpp
# ...                    ...                       ...
# 2695   5603276598621902447  phphpppphphphhpphphhphph
# 2696   2918542526153815211  hphpppphphphhpphphhphphp
# 2697  17814690177903370705  phpppphphphhpphphhphphph
# 2698  14562833835520679758  hpppphphphhpphphhphphphp
# 2699  16429938669715438102  pppphphphhpphphhphphphph
#
#               kmer_in_alphabet  start accession uniprotkb_id  \
# 0     MADEEAEQERLSCGEGGCVAELQR      0    O60281  ZN292_HUMAN
# 1     ADEEAEQERLSCGEGGCVAELQRL      1    O60281  ZN292_HUMAN
# 2     DEEAEQERLSCGEGGCVAELQRLG      2    O60281  ZN292_HUMAN
# 3     EEAEQERLSCGEGGCVAELQRLGE      3    O60281  ZN292_HUMAN
# 4     EAEQERLSCGEGGCVAELQRLGER      4    O60281  ZN292_HUMAN
# ...                        ...    ...       ...          ...
# 2695  KLEVHSNDPDMSVMKDISIGKATG   2695    O60281  ZN292_HUMAN
# 2696  LEVHSNDPDMSVMKDISIGKATGR   2696    O60281  ZN292_HUMAN
# 2697  EVHSNDPDMSVMKDISIGKATGRG   2697    O60281  ZN292_HUMAN
# 2698  VHSNDPDMSVMKDISIGKATGRGQ   2698    O60281  ZN292_HUMAN
# 2699  HSNDPDMSVMKDISIGKATGRGQY   2699    O60281  ZN292_HUMAN
#
#      organism_scientific_name organism_common_name  organism_taxonid gene_name
# 0                Homo sapiens                Human              9606    ZNF292
# 1                Homo sapiens                Human              9606    ZNF292
# 2                Homo sapiens                Human              9606    ZNF292
# 3                Homo sapiens                Human              9606    ZNF292
# 4                Homo sapiens                Human              9606    ZNF292
# ...                       ...                  ...               ...       ...
# 2695             Homo sapiens                Human              9606    ZNF292
# 2696             Homo sapiens                Human              9606    ZNF292
# 2697             Homo sapiens                Human              9606    ZNF292
# 2698             Homo sapiens                Human              9606    ZNF292
# 2699             Homo sapiens                Human              9606    ZNF292
#
# [2700 rows x 10 columns]

# %%
znf292_hashes_in_bhf = znf292_hashes.loc[znf292_hashes.hashval.isin(bhf_hashes.hashval)]
znf292_hashes_in_bhf
# Out:
#                  hashval          kmer_in_sequence          kmer_in_alphabet  \
# 606  1452226584929511062  pphhphhphppppppppppphhpp  RRLGRPPKITTTNENQKTNTVAKQ
# 609   791636867468234754  hphhphppppppppppphhppppp  GRPPKITTTNENQKTNTVAKQEQR
#
#      start accession uniprotkb_id organism_scientific_name  \
# 606    606    O60281  ZN292_HUMAN             Homo sapiens
# 609    609    O60281  ZN292_HUMAN             Homo sapiens
#
#     organism_common_name  organism_taxonid gene_name
# 606                Human              9606    ZNF292
# 609                Human              9606    ZNF292

# %%
entry.keys()
# Out:
# dict_keys(['entryType', 'primaryAccession', 'uniProtkbId', 'entryAudit', 'annotationScore', 'organism', 'proteinExistence', 'proteinDescription', 'genes', 'features', 'references', 'uniProtKBCrossReferences', 'sequence', 'extraAttributes'])

# %%
entry["primaryAccession"]

# %%
entry["uniProtkbId"]
