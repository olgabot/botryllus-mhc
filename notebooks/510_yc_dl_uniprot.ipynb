# %%
! date
# Out:
# Wed Feb  5 22:18:16 UTC 2025

# %%
! wget https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
# Out:
# --2025-02-05 22:18:17--  https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
# 128.175.240.195niprot.org (ftp.uniprot.org)...
# connected. to ftp.uniprot.org (ftp.uniprot.org)|128.175.240.195|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 92785598 (88M) [application/x-gzip]
# Saving to: ‘uniprot_sprot.fasta.gz’
#
# uniprot_sprot.fasta 100%[===================>]  88.49M  28.8MB/s    in 3.1s
#
# 2025-02-05 22:18:21 (28.8 MB/s) - ‘uniprot_sprot.fasta.gz’ saved [92785598/92785598]

# %%
! mkdir -p /home/ec2-user/s3/seanome-kmerseek/applications/botryllus/data/uniprot/2025_01/

# %%
! mv uniprot_sprot.fasta.gz /home/ec2-user/s3/seanome-kmerseek/applications/botryllus/data/uniprot/2025_01/

# %%
! ls -lha /home/ec2-user/s3/seanome-kmerseek/applications/botryllus/data/uniprot/2025_01/
# Out:
# total 89M
# drwxr-xr-x. 2 ec2-user ec2-user  36 Feb  5 22:20 .
# drwxr-xr-x. 3 ec2-user ec2-user  21 Feb  5 22:20 ..
# -rw-r--r--. 1 ec2-user ec2-user 89M Nov 27 14:00 uniprot_sprot.fasta.gz
