# %%
import pandas as pd
import os

pd.options.display.max_columns = 50

# %%
# csv ='~/botryllus/pipeline-results/kmermaid/april2021-singleton-fewer-species/gather_results__may2021/gather_results__may2021/Bs_proteins.fa__gather__human-chr6__moltype-hp__ksize-72__human_mhc_locus__GRCh38__chr6--28510120-33480577.csv'
csv = os.path.join('~',
 'botryllus',
 'pipeline-results',
 'kmermaid',
 'april2021-singleton-fewer-species',
 'gather_results__may2021',
 'Bs_proteins.fa__gather__human-chr6__moltype-hp__ksize-72__human_mhc_locus__GRCh38__chr6--28510120-33480577.csv'
                  )

mhc_matches = pd.read_csv(csv, index_col=0)
print(mhc_matches.shape)
mhc_matches.head()
# Out:
# (54284, 23)
#        intersect_bp  f_orig_query   f_match  f_unique_to_query  \
# 23500         320.0      1.000000  0.969697           1.000000
# 6393          280.0      0.965517  0.848485           0.965517
# 4485          280.0      0.965517  0.848485           0.965517
# 21440         260.0      0.866667  0.787879           0.866667
# 36123         260.0      0.361111  0.337662           0.361111
#
#        f_unique_weighted  average_abund  median_abund  std_abund  \
# 23500           1.000000            0.0           0.0        0.0
# 6393            0.965517            0.0           0.0        0.0
# 4485            0.965517            0.0           0.0        0.0
# 21440           0.866667            0.0           0.0        0.0
# 36123           0.361111            0.0           0.0        0.0
#
#                                                 filename  \
# 23500  /mnt/data_sm/olga/botryllus/pipeline-results/k...
# 6393   /mnt/data_sm/olga/botryllus/pipeline-results/k...
# ...

# %%
mhc_matches_min_kmers = mhc_matches.query('intersect_bp > 10')
mhc_matches_min_kmers.head()
# Out:
#        intersect_bp  f_orig_query   f_match  f_unique_to_query  \
# 23500         320.0      1.000000  0.969697           1.000000
# 6393          280.0      0.965517  0.848485           0.965517
# 4485          280.0      0.965517  0.848485           0.965517
# 21440         260.0      0.866667  0.787879           0.866667
# 36123         260.0      0.361111  0.337662           0.361111
#
#        f_unique_weighted  average_abund  median_abund  std_abund  \
# 23500           1.000000            0.0           0.0        0.0
# 6393            0.965517            0.0           0.0        0.0
# 4485            0.965517            0.0           0.0        0.0
# 21440           0.866667            0.0           0.0        0.0
# 36123           0.361111            0.0           0.0        0.0
#
#                                                 filename  \
# 23500  /mnt/data_sm/olga/botryllus/pipeline-results/k...
# 6393   /mnt/data_sm/olga/botryllus/pipeline-results/k...
# ...

# %%
mhc_matches_min_kmers.sample(10)
# Out:
#        intersect_bp  f_orig_query   f_match  f_unique_to_query  \
# 24275          20.0      0.080000  0.031250           0.080000
# 14852          20.0      0.017094  0.021277           0.017094
# 22038          20.0      0.117647  0.007143           0.117647
# 37365          20.0      0.026667  0.042553           0.026667
# 45971          30.0      0.111111  0.071429           0.111111
# 37222          20.0      0.500000  0.034483           0.500000
# 3322           20.0      0.058824  0.035714           0.058824
# 34032          30.0      0.130435  0.272727           0.130435
# 15820          20.0      0.285714  0.029851           0.285714
# 52071          30.0      0.032609  0.076923           0.032609
#
#        f_unique_weighted  average_abund  median_abund  std_abund  \
# 24275           0.080000            0.0           0.0        0.0
# 14852           0.017094            0.0           0.0        0.0
# 22038           0.117647            0.0           0.0        0.0
# ...

# %%
mhc_matches_min_kmers.tail()
# Out:
#        intersect_bp  f_orig_query   f_match  f_unique_to_query  \
# 25669          20.0      0.028571  0.200000           0.028571
# 4440           20.0      0.044444  0.009615           0.044444
# 4673           20.0      0.058824  0.031746           0.058824
# 32437          20.0      0.025974  0.083333           0.025974
# 32288          20.0      0.013699  0.017391           0.013699
#
#        f_unique_weighted  average_abund  median_abund  std_abund  \
# 25669           0.028571            0.0           0.0        0.0
# 4440            0.044444            0.0           0.0        0.0
# 4673            0.058824            0.0           0.0        0.0
# 32437           0.025974            0.0           0.0        0.0
# 32288           0.013699            0.0           0.0        0.0
#
#                                                 filename  \
# 25669  /mnt/data_sm/olga/botryllus/pipeline-results/k...
# 4440   /mnt/data_sm/olga/botryllus/pipeline-results/k...
# ...

# %%
mhc_matches_min_kmers.loc[~mhc_matches_min_kmers.query_name.str.startswith('g')]
# Out:
#    intersect_bp  f_orig_query   f_match  f_unique_to_query  f_unique_weighted  \
# 0          20.0      0.095238  0.007143           0.095238           0.095238
#
#    average_abund  median_abund  std_abund  \
# 0            0.0           0.0        0.0
#
#                                             filename  \
# 0  /mnt/data_sm/olga/botryllus/pipeline-results/k...
#
#                                                 name  \
# 0  ENSP00000342847.4pep chromosome:GRCh38:6:87155...
#
#                                 md5  f_match_orig query_name moltype  ksize  \
# 0  e5b39c41cc3d733afdb0c121c073df1e      0.007143        BHF      hp     72
#
#        species Source              description                gene  \
# 0  Bs_proteins   HGNC  zinc finger protein 292  ENSG00000188994.13
#
#      gene_biotype gene_symbol         transcript transcript_biotype
# 0  protein_coding      ZNF292  ENST00000339907.8     protein_coding

# %%
n_matches_per_query = mhc_matches_min_kmers.query_name.value_counts()
n_matches_per_query.head()
# Out:
# g17900.t1 frame:1    6
# g59676.t1 frame:1    6
# g30690.t1 frame:3    5
# g7851.t1 frame:1     5
# g574.t1 frame:1      5
# Name: query_name, dtype: int64

# %%
n_matches_per_query

# %%
mhc_matches_min_kmers.query('query_name == "g17900.t1 frame:1"')
# Out:
#        intersect_bp  f_orig_query   f_match  f_unique_to_query  \
# 12867          70.0      0.081395  0.155556           0.081395
# 12869          60.0      0.069767  0.023810           0.023256
# 12873          60.0      0.069767  0.012987           0.011628
# 12871          60.0      0.069767  0.010309           0.011628
# 12868          30.0      0.034884  0.300000           0.034884
# 12870          20.0      0.023256  0.008065           0.023256
#
#        f_unique_weighted  average_abund  median_abund  std_abund  \
# 12867           0.081395            0.0           0.0        0.0
# 12869           0.023256            0.0           0.0        0.0
# 12873           0.011628            0.0           0.0        0.0
# 12871           0.011628            0.0           0.0        0.0
# 12868           0.034884            0.0           0.0        0.0
# 12870           0.023256            0.0           0.0        0.0
#
#                                                 filename  \
# ...

# %%
mhc_matches_min_kmers.query('query_name == "g59676.t1 frame:1"')
# Out:
#        intersect_bp  f_orig_query   f_match  f_unique_to_query  \
# 44792          20.0      0.004158  0.028169           0.004158
# 44793          20.0      0.004158  0.057143           0.004158
# 44794          20.0      0.004158  0.005900           0.004158
# 44795          20.0      0.004158  0.030769           0.004158
# 44796          20.0      0.004158  0.007663           0.004158
# 44813          20.0      0.004158  0.037037           0.002079
#
#        f_unique_weighted  average_abund  median_abund  std_abund  \
# 44792           0.004158            0.0           0.0        0.0
# 44793           0.004158            0.0           0.0        0.0
# 44794           0.004158            0.0           0.0        0.0
# 44795           0.004158            0.0           0.0        0.0
# 44796           0.004158            0.0           0.0        0.0
# 44813           0.002079            0.0           0.0        0.0
#
#                                                 filename  \
# ...

# %%
mhc_matches_min_kmers.query_name.nunique()
# Out:
# 5355
